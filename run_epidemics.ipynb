# %%
# !python3 /home/users/rluna/epidemics/Infected-Detection/treina_gnn.py
# Out:
# Starting script
# Reading configurations from treina_gnn_config.yaml
# Getting data from folder /home/users/rluna/epidemics/dataset/results/BA_obs50/BA.
# Model will be trained with the following inputs: ['OBS_I', 'DEG', 'CONT', 'BETW', 'OBS_B']
# Created data set with 1000 instances
# Split data into train (801 instances) and test (199 instances) sets
# Epoch 1/100, Train Loss: 0.6761612892150879
# Epoch 2/100, Train Loss: 0.39002443477511406
# Epoch 3/100, Train Loss: 0.31443218514323235
# Epoch 4/100, Train Loss: 0.31353454664349556
# Epoch 5/100, Train Loss: 0.31341099739074707
# Epoch 6/100, Train Loss: 0.31337230280041695
# Epoch 7/100, Train Loss: 0.3133545368909836
# Epoch 8/100, Train Loss: 0.31334152817726135
# Epoch 9/100, Train Loss: 0.313329316675663
# Epoch 10/100, Train Loss: 0.31331897899508476
# Epoch 10/100, Val Loss: 0.3133
# Epoch 11/100, Train Loss: 0.3133094273507595
# Epoch 12/100, Train Loss: 0.313302181661129
# Epoch 13/100, Train Loss: 0.3132968582212925
# ...

# %%
import pickle
file_pkl = '/home/users/rluna/epidemics/dataset/results/BA/instance_modelBA-m4n3000_epidemic-ii1-t0-f0.2_run999.pkl'

import pickle

with open(file_pkl, 'rb') as f:
    obj = pickle.load(f)

# %%
import yaml
file = '//home/users/rluna/epidemics/dataset/results/BA_obs50/BA/stats_model-dl128-lr0.0001-ep100_data-testsBA_s0.dict'
with open(file, 'r') as f:
    stats = yaml.safe_load(f)

# %%
print(stats)
# Out:
# {'config': {'Random seed': 0, 'dataset': {'batch_size': 128, 'inputs': ['OBS_I', 'DEG', 'CONT', 'OBS_B'], 'name': 'testsBA', 'path': '/home/users/rluna/epidemics/dataset/results/BA_obs50/BA', 'size': 1000, 'split': {'seed': 0, 'train_proportion': 0.8}}, 'model': {'dim_layer': 128, 'epochs': 100, 'learning_rate': 0.0001}}, 'test': {'1st quartile': 0.7234588424185464, '3rd quartile': 0.7804831815276446, 'max': 0.8315304232804234, 'mean': 0.7528256094934159, 'median': 0.7480235745614036, 'min': 0.6611893203883495, 'number of instances': 199.0, 'std': 0.03713573628941238}, 'train': {'1st quartile': 0.7265002796420581, '3rd quartile': 0.7784250568828214, 'max': 0.8418633040935672, 'mean': 0.7519481491925122, 'median': 0.7525673817381738, 'min': 0.6530387931034483, 'number of instances': 801.0, 'std': 0.03448668779924442}}

# %%
# !mv /home/users/rluna/epidemics/dataset/results/BA/BA_n3000_m4/BA/*.pkl /home/users/rluna/epidemics/dataset/results/BA/

# %%
# !unzip /home/users/rluna/epidemics/dataset/results/BA/BA_n3000_m4-20250411T211509Z-001.zip
# Out:
# Archive:  /home/users/rluna/epidemics/dataset/results/BA/BA_n3000_m4-20250411T211509Z-001.zip
#   inflating: BA_n3000_m4/BA/instance_modelBA-m4n3000_epidemic-ii1-t0-f0.2_run994.pkl
#   inflating: BA_n3000_m4/BA/instance_modelBA-m4n3000_epidemic-ii1-t0-f0.2_run982.pkl
#   inflating: BA_n3000_m4/BA/instance_modelBA-m4n3000_epidemic-ii1-t0-f0.2_run985.pkl
#   inflating: BA_n3000_m4/BA/instance_modelBA-m4n3000_epidemic-ii1-t0-f0.2_run974.pkl
#   inflating: BA_n3000_m4/BA/instance_modelBA-m4n3000_epidemic-ii1-t0-f0.2_run964.pkl
#   inflating: BA_n3000_m4/BA/instance_modelBA-m4n3000_epidemic-ii1-t0-f0.2_run970.pkl
#   inflating: BA_n3000_m4/BA/instance_modelBA-m4n3000_epidemic-ii1-t0-f0.2_run987.pkl
#   inflating: BA_n3000_m4/BA/instance_modelBA-m4n3000_epidemic-ii1-t0-f0.2_run995.pkl
#   inflating: BA_n3000_m4/BA/instance_modelBA-m4n3000_epidemic-ii1-t0-f0.2_run988.pkl
#   inflating: BA_n3000_m4/BA/instance_modelBA-m4n3000_epidemic-ii1-t0-f0.2_run998.pkl
# ...
